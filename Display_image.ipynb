# %% [markdown]
# <h1>Een afbeelding weergeven in een python notebook</h1>
# <p>In een eerste stap gaan we een gewone .jpg of .png inladen en weergeven in het notebook</p>

# %% [markdown]
# <h1>1. Bibiliotheken installeren en inladen</h1>

# %%
pip install opencv-python
# Out:
# ...
#      |████████████████████████████████| 49.9 MB 7.9 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# import the necessary packages
from matplotlib import pyplot as plt
import argparse
import cv2

# %% [markdown]
# <h1>2. functie voor het weergeven van de afbeelding definieren</h1>

# %%
def plt_imshow(title, image):
    # convert the image frame BGR to RGB color space and display it
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    plt.imshow(image)
    plt.title(title)
    plt.grid(False)
    plt.show()

# %% [markdown]
# <h1>3. Afbeelding oproepen aan de hand van zijn bestandsnaam</h1>

# %%
args = {
     "image": "hond.png",
}

# %% [markdown]
# <h1>4. Afbeelding inladen en specificaties weergeven</h1>

# %%
image = cv2.imread(args["image"])
(h, w, c) = image.shape[:3]


print("Breedte: {} pixels".format(image.shape[1]))
print("Hoogte: {}  pixels".format(image.shape[0]))
# Out:
# Breedte: 480 pixels
# Hoogte: 300  pixels

# %% [markdown]
# <h1>5. Afbeelding weergeven door de methode op te roepen</h1>

# %%
plt_imshow("Image", image)

# met dit commando kan je de afbeelding opslaan onder een nieuwe bestandsnaam
cv2.imwrite("newimage.jpg", image)
# Out:
# True
